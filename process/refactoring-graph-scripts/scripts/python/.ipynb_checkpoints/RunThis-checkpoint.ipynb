# %%
import RQFunctions as rqfunc
import graph_generator

# %%
print('Select which Language\'s stats you want to know')
print('1 - Java Projects')
print('2 - C++ Projects')
lang = int(input('\nOption: '))
# Out:
# Select which Language's stats you want to know
# 1 - Java Projects
# 2 - C++ Projects

# %%
langs = {
    1: 'java',
    2: 'cpp'
  }
rqfunc.setGraphProps('../../../../data/dataset/{}_subgraphs_properties.csv'.format(langs[lang]))

# %% [markdown]
# # (RQ1) What Is the Size of Refactoring Subgraphs?

# %%
rqfunc.noOfVertices()

# %%
rqfunc.noOfEdges()

# %% [markdown]
# # (RQ2) How Many Commits Are in Refactoring Subgraphs?

# %%
rqfunc.noOfCommits()

# %% [markdown]
# # (RQ3) What Is the Age of Refactoring Subgraphs?

# %%
rqfunc.ageRefactorinmgGraph()
