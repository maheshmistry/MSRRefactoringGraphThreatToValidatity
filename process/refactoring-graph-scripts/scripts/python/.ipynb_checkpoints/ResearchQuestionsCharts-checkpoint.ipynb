# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
graphsProp = pd.read_csv('../../dataset/saner-2020/subgraphs_properties.csv',';')
graphsProp
# Out:
#        id                           project  vertices  edges  age_days  \
# 0       2  spring-projects/spring-framework         5      4        51
# 1       5  spring-projects/spring-framework        15     14       286
# 2      11  spring-projects/spring-framework         4      3      1103
# 3      14  spring-projects/spring-framework         3      2        45
# 4      15  spring-projects/spring-framework         3      3       847
# ...   ...                               ...       ...    ...       ...
# 1145  420            PhilJay/MPAndroidChart         3      2        15
# 1146  421            PhilJay/MPAndroidChart         3      2        15
# 1147  422            PhilJay/MPAndroidChart         3      2        15
# 1148  433            PhilJay/MPAndroidChart        44     61        76
# 1149  441            PhilJay/MPAndroidChart         3      2         1
#
#       developers  distinct_operations  commits
# 0              2                    2        2
# 1              2                    2        2
# 2              3                    3        3
# 3              1                    1        2
# 4              3                    2        3
# ...          ...                  ...      ...
# 1145           1                    2        2
# 1146           1                    2        2
# 1147           1                    2        2
# 1148           2                    4        8
# 1149           1                    1        2
#
# [1150 rows x 8 columns]

# %% [markdown]
# # (RQ1) What Is the Size of Refactoring Subgraphs?

# %%
verOccu = graphsProp['vertices'].value_counts()
sixPlus = 0
# print(type(verOccu))
for keys in verOccu.keys():
#     print(keys)
    if keys >= 6:
#         print([keys])
        sixPlus = sixPlus + verOccu[keys]
        verOccu = verOccu.drop(keys)

verOccu = verOccu.sort_index()   
verOccu['6+'] = sixPlus
verOccu.plot.bar(xlabel='Vertices', ylabel='Occurence', title='Number of vertices by refactoring subgraph')
# Out:
# <AxesSubplot:title={'center':'Number of vertices by refactoring subgraph'}, xlabel='Vertices', ylabel='Occurence'>

# %%
edgeOccu = graphsProp['edges'].value_counts()
fivePlus = 0
# print(type(verOccu))
for keys in edgeOccu.keys():
#     print(keys)
    if keys >= 5:
#         print([keys])
        fivePlus = fivePlus + edgeOccu[keys]
        edgeOccu = edgeOccu.drop(keys)

edgeOccu = edgeOccu.sort_index()   
edgeOccu['5+'] = fivePlus
edgeOccu.plot.bar(xlabel='Edges', ylabel='Occurence', title='Number of edges by refactoring subgraph')
# Out:
# <AxesSubplot:title={'center':'Number of edges by refactoring subgraph'}, xlabel='Edges', ylabel='Number of Edges'>

# %% [markdown]
# # (RQ2) How Many Commits Are in Refactoring Subgraphs?

# %%
commitOccu = graphsProp['commits'].value_counts()
fivePlus = 0
# print(type(verOccu))
for keys in commitOccu.keys():
#     print(keys)
    if keys >= 5:
#         print([keys])
        fivePlus = fivePlus + commitOccu[keys]
        commitOccu = commitOccu.drop(keys)

commitOccu = commitOccu.sort_index()   
commitOccu['5+'] = fivePlus
commitOccu.plot.bar(xlabel='Commits', ylabel='Occurence', title='Number of commits by refactoring subgraph')
# Out:
# <AxesSubplot:title={'center':'Number of commits by refactoring subgraph'}, xlabel='Commits', ylabel='Occurence'>

# %% [markdown]
# # (RQ3) What Is the Age of Refactoring Subgraphs?

# %%
slimedProp = graphsProp[['project','age_days']].copy()

slimedProp.groupby('project').boxplot(column='age_days', figsize=(25,25))
# Out:
# PhilJay/MPAndroidChart                   AxesSubplot(0.1,0.736957;0.235294x0.163043)
# ReactiveX/RxJava                    AxesSubplot(0.382353,0.736957;0.235294x0.163043)
# airbnb/lottie-android               AxesSubplot(0.664706,0.736957;0.235294x0.163043)
# apache/dubbo                             AxesSubplot(0.1,0.541304;0.235294x0.163043)
# bumptech/glide                      AxesSubplot(0.382353,0.541304;0.235294x0.163043)
# elastic/elasticsearch               AxesSubplot(0.664706,0.541304;0.235294x0.163043)
# facebook/fresco                          AxesSubplot(0.1,0.345652;0.235294x0.163043)
# spring-projects/spring-framework    AxesSubplot(0.382353,0.345652;0.235294x0.163043)
# square/okhttp                       AxesSubplot(0.664706,0.345652;0.235294x0.163043)
# square/retrofit                              AxesSubplot(0.1,0.15;0.235294x0.163043)
# dtype: object

# %% [markdown]
# # (RQ4) Which Refactorings Compose the Refactoring Sub-graphs?

# %% [markdown]
# With the generated data from the previous scripts by authors it is not possible to count the frequency of the refactoring operations.

# %% [markdown]
# # (RQ5) Are the Refactoring Subgraphs Created by the Same or Multiple Developers?

# %%
proDevProp = graphsProp[['project','developers']].copy()

devProDict = {}
for index, row in proDevProp.iterrows():
    if row['developers'] > 1:
        devProDict['m'] = devProDict['m'] + 1
    else:
        devProDict['singledev'] = devProDict['singledev'] + 1
        
devProList
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-6d1b6dd86ba2> in <module>
#       4 for index, row in proDevProp.iterrows():
#       5     if row['developers'] > 1:
# ----> 6         devProList['m'] = devProList['m'] + 1
#       7     else:
#       8         devProList['singledev'] = devProList['singledev'] + 1
#
# KeyError: 'm'
